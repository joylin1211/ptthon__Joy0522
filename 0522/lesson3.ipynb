# %%
score=int(input("請輸入學生的分數,最高300分"))
a=input("請確認這位學生是否要加分(y,n)")

if a =="y":
    score=score*1.05

print("這位學生的總分是=",score)
# Out:
# 這位學生的總分是= 252.0

# %%
try:
    score = int(input("請輸入你的成績"))
    print(score)
except ValueError:
    print("出錯了，請輸入數字")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       3     print(score)
#       4 except:
# ----> 5     print("出錯了")
#
# TypeError: 'int' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       1 try:
#       2     score=int(input("請輸入你的成績"))
#       3     print(score)
#       4 except:
# ----> 5     print("出錯了")
#
# TypeError: 'int' object is not callable
